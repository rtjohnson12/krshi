# %% [markdown]
# # Exploration of India Crop Production (1997 - 2015)

# %% [markdown]
# ## Set-Up
#
# Here we import the required libraries, and load the unzipped data into the workspace.

# %%
import pandas as pd 
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# read crop data
df = pd.read_csv('../data/crop_production.csv')

# read shape file
shp_gdf = gpd.read_file('../data/Indian_states.shp').rename(columns = {'st_nm' : 'State_Name'})
df = shp_gdf.set_index('State_Name').join(df.set_index('State_Name')).reset_index()

# %% [markdown]
# ### Take a Quick Look at data structure

# %%
df.head()
# Out:
#                  State_Name  \
# 0  Andaman & Nicobar Island
# 1            Andhra Pradesh
# 2            Andhra Pradesh
# 3            Andhra Pradesh
# 4            Andhra Pradesh
#
#                                             geometry District_Name  Crop_Year  \
# 0  MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...           NaN        NaN
# 1  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...     ANANTAPUR     1997.0
# 2  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...     ANANTAPUR     1997.0
# 3  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...     ANANTAPUR     1997.0
# 4  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...     ANANTAPUR     1997.0
#
#         Season          Crop     Area  Production
# 0          NaN           NaN      NaN         NaN
# 1  Kharif          Arhar/Tur  21400.0      2600.0
# 2  Kharif              Bajra   1400.0       500.0
# 3  Kharif        Castor seed   1000.0       100.0
# 4  Kharif       Cotton(lint)   7300.0      9400.0

# %%
df.hist(bins = 50, figsize = (12, 8))
# Out:
# array([[<AxesSubplot:title={'center':'Crop_Year'}>,
#         <AxesSubplot:title={'center':'Area'}>],
#        [<AxesSubplot:title={'center':'Production'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
fig, ax = plt.subplots(1, figsize = (12, 12))
ax.axis('off')
ax.set_title('Crop Production in India', fontdict = {'fontsize':'15', 'fontweight':'3'})
fig = df.plot(column = 'Production', cmap = 'RdYlGn', linewidth = 0.5, ax = ax, edgecolor = '0.2', legend = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/d7/vzxy3qb52r312170_4tkrrd00000gn/T/ipykernel_39688/2698910630.py in <module>
#       2 ax.axis('off')
#       3 ax.set_title('Crop Production in India', fontdict = {'fontsize':'15', 'fontweight':'3'})
# ----> 4 fig = df.plot(column = 'Production', cmap = 'RdYlGn', linewidth = 0.5, ax = ax, edgecolor = '0.2', legend = True)
#
# ~/Documents/Projects/krshi/.venv/lib/python3.9/site-packages/geopandas/plotting.py in __call__(self, *args, **kwargs)
#     923             kind = kwargs.pop("kind", "geo")
#     924             if kind == "geo":
# --> 925                 return plot_dataframe(data, *args, **kwargs)
#     926             if kind in self._pandas_kinds:
#     927                 # Access pandas plots
#
# ...

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
df[(df['Crop'] == 'Rice') & (df['Crop_Year'] == 2014)].groupby('State_Name').head()
# Out:
#             State_Name                                           geometry  \
# 751     Andhra Pradesh  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...
# 779     Andhra Pradesh  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...
# 788     Andhra Pradesh  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...
# 1544    Andhra Pradesh  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...
# 1569    Andhra Pradesh  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...
# ...                ...                                                ...
# 226627     West Bengal  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# 226647     West Bengal  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# 226650     West Bengal  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# 227061     West Bengal  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
# 227078     West Bengal  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...
#
#              District_Name  Crop_Year       Season  Crop      Area  Production
# ...

# %%
fig, ax = plt.subplots(1, figsize=(5, 12))
ax.axis('off')
ax.set_title('Crop Production in India (1997)',
             fontdict={'fontsize': '15', 'fontweight' : '3'})
fig = plot_df.plot(column='Production', cmap='RdYlGn', linewidth=0.5, ax=ax, edgecolor='0.2',legend=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/d7/vzxy3qb52r312170_4tkrrd00000gn/T/ipykernel_39688/1575200522.py in <module>
#       3 ax.set_title('Crop Production in India (1997)',
#       4              fontdict={'fontsize': '15', 'fontweight' : '3'})
# ----> 5 fig = plot_df.plot(column='Production', cmap='RdYlGn', linewidth=0.5, ax=ax, edgecolor='0.2',legend=True)
#
# ~/Documents/Projects/krshi/.venv/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/Documents/Projects/krshi/.venv/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...
